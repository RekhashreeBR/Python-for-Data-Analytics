# %% [markdown]
# ## **FACTOR ANALYSIS**

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from factor_analyzer.factor_analyzer import calculate_bartlett_sphericity,calculate_kmo
from factor_analyzer import FactorAnalyzer

# %%
fadata=pd.read_csv(r"D:\231bcada34\4 th sem\MVS\FactorAnalysis.csv")
fadata
# Out:
#     Academic record  Appearance  Communication  Company Fit  Experience  \
# 0                 6           8              7            5           6
# 1                 9           8              8            8          10
# 2                 6           7              7            6           6
# 3                 7           8              6            5           8
# 4                 4           7              8            6           6
# 5                 7           7              7            5           5
# 6                 6           8              6            7           7
# 7                 7           6              6            5           8
# 8                 9           8              8            9           9
# 9                 6           8              7            8           6
# 10                6           8              8            6           5
# 11                6           6              3            5           7
# ...

# %%
std_fadata=StandardScaler().fit_transform(fadata)
std_fadata
# Out:
# array([[-1.09321633,  0.55821656,  0.09614333, -1.1691687 , -0.97909487,
#         -1.27766239, -0.13311106, -0.34185713,  0.08961847, -0.94561086,
#         -0.14388034, -0.29323423],
#        [ 1.2493901 ,  0.55821656,  0.78288136,  0.69652603,  1.98785928,
#          1.25236215,  0.4719392 ,  1.45739094,  0.7297504 ,  1.23656804,
#          1.0551225 ,  1.431673  ],
#        [-1.09321633, -0.43859872,  0.09614333, -0.54727045, -0.97909487,
#         -0.01265012, -0.13311106,  0.5577669 ,  0.7297504 , -0.94561086,
#         -0.74338176,  0.56921939],
#        [-0.31234752,  0.55821656, -0.59059471, -1.1691687 ,  0.5043822 ,
#         -1.27766239,  1.07698945,  0.5577669 ,  0.08961847,  0.50917508,
#         -0.14388034, -0.29323423],
#        [-2.65495395, -0.43859872,  0.78288136, -0.54727045, -0.97909487,
#         -0.64515626, -0.73816131, -0.34185713,  0.7297504 , -1.67300383,
#         -1.94238461, -1.15568785],
# ...

# %%
print(std_fadata.mean().round(6))
print(std_fadata.std(ddof=0).round(6))
# Out:
# -0.0
# 1.0

# %%
chi2,p=calculate_bartlett_sphericity(fadata)
print(chi2," =chi")
print(p.round(5)," =p_value")
# Out:
# 472.514673149833  =chi
# 0.0  =p_value

# %%
kmo_col,kmo_whole=calculate_kmo(fadata)
print("kmo of each col =",kmo_col)
print("kmo of entire data =",kmo_whole)
# Out:
# kmo of each col = [0.84674275 0.87575542 0.79007184 0.80851662 0.78198521 0.82659814
#  0.67602071 0.85053555 0.74012888 0.88260046 0.71201154 0.77743459]
# kmo of entire data = 0.7979087431160229

# %%
fa=FactorAnalyzer(n_factors=5,rotation="varimax")

# %%
fa.fit(std_fadata)
# Out:
# C:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# FactorAnalyzer(n_factors=5, rotation='varimax', rotation_kwargs={})

# %%
fadata_col=np.array(list(fadata.columns),dtype=object)
fadata_col
# Out:
# array(['Academic record', 'Appearance', 'Communication', 'Company Fit',
#        'Experience', 'Job Fit', 'Letter', 'Likeability', 'Organization',
#        'Potential', 'Resume', 'Self-Confidence'], dtype=object)

# %%
print(pd.DataFrame(fa.loadings_,index=fadata_col))
# Out:
#                         0         1         2         3         4
# Academic record  0.817449  0.207404  0.214648  0.136908  0.138510
# Appearance       0.268514  0.662850  0.316509  0.173361  0.054559
# Communication    0.139019  0.246105  0.832407  0.208066  0.192794
# Company Fit      0.290424  0.214759  0.385727  0.196068  0.724549
# Experience       0.698473  0.172675 -0.057251  0.331203  0.195021
# Job Fit          0.364802  0.236846  0.228228  0.210248  0.817705
# Letter           0.169976  0.067956  0.177199  0.908530  0.201651
# Likeability      0.155294  0.718104  0.246577  0.192744  0.236334
# Organization     0.093029  0.321561  0.837179  0.085286  0.260208
# Potential        0.776730  0.281260  0.182109  0.130870  0.364659
# Resume           0.282505  0.314470  0.127379  0.801106  0.100226
# Self-Confidence  0.220464  0.858425  0.158626  0.088903  0.171200

# %%
print(pd.DataFrame(fa.get_communalities(),index=fadata_col))
# Out:
#                         0
# Academic record  0.795242
# Appearance       0.644678
# Communication    0.853257
# Company Fit      0.842667
# Experience       0.668687
# Job Fit          0.954110
# Letter           0.931000
# Likeability      0.693594
# Organization     0.887906
# Potential        0.865683
# Resume           0.846742
# Self-Confidence  0.847874

# %%
print(pd.DataFrame(fa.get_uniquenesses(),index=fadata_col))
# Out:
#                         0
# Academic record  0.204758
# Appearance       0.355322
# Communication    0.146743
# Company Fit      0.157333
# Experience       0.331313
# Job Fit          0.045890
# Letter           0.069000
# Likeability      0.306406
# Organization     0.112094
# Potential        0.134317
# Resume           0.153258
# Self-Confidence  0.152126

# %%
print(pd.DataFrame(fa.get_factor_variance(),index=["variance","proportional var","totl vari"]))
# Out:
#                          0         1         2         3         4
# variance          2.258326  2.213574  1.910924  1.821085  1.627533
# proportional var  0.188194  0.184464  0.159244  0.151757  0.135628
# totl vari         0.188194  0.372658  0.531902  0.683659  0.819287
